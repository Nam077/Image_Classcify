# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
from time import perf_counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score
from IPython.display import Markdown, display
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Activation,Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical 
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras import backend, models
from sklearn.metrics import confusion_matrix

from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator

# %%
labels = os.listdir('data/')
print(labels)
# Out:
# ['airplane', 'car', 'cat', 'dog', 'flower', 'fruit', 'motorbike', 'person']

# %%
from IPython.display import Image, display
num = []
for label in labels:
    path = 'data/{0}/'.format(label)
    folder_data = os.listdir(path)
    k = 0
    print('\n', label.upper())
    for image_path in folder_data:
        if k < 2:
            display(Image(path+image_path))
        k = k+1
    num.append(k)
    print('there are ', k,' images in ', label, 'class')
# Out:
#  AIRPLANE
# there are  727  images in  airplane class
#
#  CAR
# there are  968  images in  car class
#
#  CAT
# there are  885  images in  cat class
#
#  DOG
# there are  702  images in  dog class
#
#  FLOWER
# there are  843  images in  flower class
#
#  FRUIT
# there are  1000  images in  fruit class
#
#  MOTORBIKE
# there are  788  images in  motorbike class
#
#  PERSON
# there are  986  images in  person class

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))
plt.bar(labels, num)
plt.title('NUMBER OF IMAGES CONTAINED IN EACH CLASS')
plt.xlabel('classes')
plt.ylabel('count')
plt.show()

# %%
x_data =[]
y_data = []
import cv2
for label in labels:
    path = 'data/{0}/'.format(label)
    folder_data = os.listdir(path)
    for image_path in folder_data:
        image = cv2.imread(path+image_path)
        image_resized = cv2.resize(image, (32,32))
        x_data.append(np.array(image_resized))
        y_data.append(label)

# %%
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
x_data.shape
# Out:
# (6899, 32, 32, 3)

# %%
y_data.shape
# Out:
# (6899,)

# %%
#converting the y_data into categorical:
y_encoded = LabelEncoder().fit_transform(y_data)
y_categorical = to_categorical(y_encoded)

# %%
r = np.arange(x_data.shape[0])
np.random.seed(42)
np.random.shuffle(r)
X = x_data[r]
Y = y_categorical[r]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
model = Sequential()
#kernel size
model.add(Conv2D(64, (3, 3), padding='same',input_shape=X_train.shape[1:])) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3))) 
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization()) 

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(BatchNormalization())
model.add(Dropout(0.35)) #64 --> 42

model.add(Conv2D(64, (3, 3), padding='same')) 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Flatten()) 
model.add(Dropout(0.5)) 
#
model.add(Dense(512)) 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dense(8)) 
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  activation (Activation)     (None, 32, 32, 64)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 64)       256
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 64)        36928
#
#  activation_1 (Activation)   (None, 30, 30, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 64)       0
#  )
#
#  batch_normalization_1 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  dropout (Dropout)           (None, 15, 15, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        36928
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  batch_normalization_2 (Batc  (None, 15, 15, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)          36928
#
#  activation_4 (Activation)   (None, 6, 6, 64)          0
#
#  batch_normalization_4 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dropout_2 (Dropout)         (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  activation_5 (Activation)   (None, 512)               0
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 8)                 4104
#
#  activation_6 (Activation)   (None, 8)                 0
#
# =================================================================
# Total params: 1,337,096
# Trainable params: 1,335,432
# Non-trainable params: 1,664
# _________________________________________________________________

# %%
model.compile(
    loss='categorical_crossentropy', 
    optimizer='adam', 
    metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=25, validation_split=0.2)
# Out:
# Epoch 1/25
# 138/138 [==============================] - 28s 190ms/step - loss: 1.0145 - accuracy: 0.6858 - val_loss: 1.2332 - val_accuracy: 0.6114
# Epoch 2/25
# 138/138 [==============================] - 32s 234ms/step - loss: 0.5094 - accuracy: 0.8170 - val_loss: 0.4880 - val_accuracy: 0.8207
# Epoch 3/25
# 138/138 [==============================] - 24s 174ms/step - loss: 0.3727 - accuracy: 0.8643 - val_loss: 0.3977 - val_accuracy: 0.8505
# Epoch 4/25
# 138/138 [==============================] - 24s 177ms/step - loss: 0.3220 - accuracy: 0.8815 - val_loss: 0.3756 - val_accuracy: 0.8705
# Epoch 5/25
# 138/138 [==============================] - 26s 191ms/step - loss: 0.2680 - accuracy: 0.8983 - val_loss: 0.3655 - val_accuracy: 0.8768
# Epoch 6/25
# 138/138 [==============================] - 26s 190ms/step - loss: 0.2186 - accuracy: 0.9205 - val_loss: 0.3722 - val_accuracy: 0.8768
# Epoch 7/25
# 138/138 [==============================] - 28s 204ms/step - loss: 0.2146 - accuracy: 0.9219 - val_loss: 0.3528 - val_accuracy: 0.8886
# Epoch 8/25
# 138/138 [==============================] - 31s 224ms/step - loss: 0.1843 - accuracy: 0.9282 - val_loss: 0.3450 - val_accuracy: 0.8904
# Epoch 9/25
# 138/138 [==============================] - 28s 200ms/step - loss: 0.1664 - accuracy: 0.9334 - val_loss: 0.2889 - val_accuracy: 0.9049
# Epoch 10/25
# 138/138 [==============================] - 28s 200ms/step - loss: 0.1423 - accuracy: 0.9472 - val_loss: 0.3611 - val_accuracy: 0.8850
# Epoch 11/25
# 138/138 [==============================] - 27s 194ms/step - loss: 0.1380 - accuracy: 0.9486 - val_loss: 0.2306 - val_accuracy: 0.9257
# Epoch 12/25
# 138/138 [==============================] - 26s 191ms/step - loss: 0.1152 - accuracy: 0.9581 - val_loss: 0.6438 - val_accuracy: 0.8216
# Epoch 13/25
# 138/138 [==============================] - 26s 192ms/step - loss: 0.0939 - accuracy: 0.9647 - val_loss: 0.3152 - val_accuracy: 0.9013
# Epoch 14/25
# 138/138 [==============================] - 27s 197ms/step - loss: 0.1072 - accuracy: 0.9622 - val_loss: 0.5121 - val_accuracy: 0.8542
# Epoch 15/25
# 138/138 [==============================] - 29s 210ms/step - loss: 0.0987 - accuracy: 0.9642 - val_loss: 0.2792 - val_accuracy: 0.9167
# Epoch 16/25
# 138/138 [==============================] - 27s 197ms/step - loss: 0.0912 - accuracy: 0.9658 - val_loss: 0.3705 - val_accuracy: 0.8795
# Epoch 17/25
# 138/138 [==============================] - 31s 224ms/step - loss: 0.1048 - accuracy: 0.9604 - val_loss: 0.2587 - val_accuracy: 0.9248
# Epoch 18/25
# 138/138 [==============================] - 29s 209ms/step - loss: 0.0835 - accuracy: 0.9699 - val_loss: 0.3670 - val_accuracy: 0.8913
# Epoch 19/25
# 138/138 [==============================] - 33s 238ms/step - loss: 0.0784 - accuracy: 0.9708 - val_loss: 0.2711 - val_accuracy: 0.9167
# Epoch 20/25
# 138/138 [==============================] - 30s 217ms/step - loss: 0.0814 - accuracy: 0.9710 - val_loss: 0.5478 - val_accuracy: 0.8641
# Epoch 21/25
# 138/138 [==============================] - 30s 221ms/step - loss: 0.0828 - accuracy: 0.9696 - val_loss: 0.2883 - val_accuracy: 0.9203
# Epoch 22/25
# 138/138 [==============================] - 29s 213ms/step - loss: 0.0749 - accuracy: 0.9740 - val_loss: 0.2933 - val_accuracy: 0.9130
# Epoch 23/25
# 138/138 [==============================] - 27s 199ms/step - loss: 0.0732 - accuracy: 0.9730 - val_loss: 0.2885 - val_accuracy: 0.9158
# Epoch 24/25
# 138/138 [==============================] - 30s 217ms/step - loss: 0.0617 - accuracy: 0.9794 - val_loss: 0.2810 - val_accuracy: 0.9185
# Epoch 25/25
# 138/138 [==============================] - 28s 206ms/step - loss: 0.0648 - accuracy: 0.9764 - val_loss: 0.2547 - val_accuracy: 0.9221

# %%
from tensorflow.python.keras.saving.save import load_model

# %%
model.save("model.h5")
